# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
listings = pd.read_csv("/content/cleaned_listing_v3")

# %% [markdown]
# # Data Preprocessing/Validity Check

# %%
listings = listings.assign(
    listing_id = lambda x: x.listing_id.astype("object")
)

# %%
calendar = pd.read_csv("/content/cleaned_calendar_v3")
# Out:
# /tmp/ipython-input-1292462284.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   calendar = pd.read_csv("/content/cleaned_calendar_v3")

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1225881 entries, 0 to 1225880
# Data columns (total 6 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   listing_id      1225881 non-null  int64
#  1   date            1225880 non-null  object
#  2   available       1225880 non-null  object
#  3   minimum_nights  1225880 non-null  float64
#  4   maximum_nights  1225880 non-null  float64
#  5   price           1225880 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 56.1+ MB

# %%
calendar = calendar.assign(
    listing_id = lambda x: x.listing_id.astype('object'),
    date = lambda x: pd.to_datetime(x.date)
)

# %%
calendar.minimum_nights.isna().sum()
# Out:
# np.int64(1)

# %%
calendar.maximum_nights.isna().sum()
# Out:
# np.int64(1)

# %%
drop_empty_row = calendar.loc[(calendar.minimum_nights.isna()) | (calendar.maximum_nights.isna())].index

# %%
calendar.shape[0]
# Out:
# 1225881

# %%
calendar.drop(drop_empty_row, axis=0, inplace=True)

# %%
calendar = calendar.assign(
    minimum_nights = lambda x: x.minimum_nights.astype('int64'),
    maximum_nights = lambda x: x.maximum_nights.astype('int64')
)

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1225880 entries, 0 to 1225879
# Data columns (total 7 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   listing_id      1225880 non-null  object
#  1   date            1225880 non-null  datetime64[ns]
#  2   available       1225880 non-null  object
#  3   minimum_nights  1225880 non-null  int64
#  4   maximum_nights  1225880 non-null  int64
#  5   price           1225880 non-null  float64
#  6   booked          1225880 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 65.5+ MB

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4741 entries, 0 to 4740
# Data columns (total 62 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   listing_id                                    4741 non-null   object
#  1   name                                          4741 non-null   object
#  2   description                                   4680 non-null   object
#  3   neighborhood_overview                         2977 non-null   object
#  4   host_name                                     4739 non-null   object
#  5   host_since                                    4739 non-null   object
#  6   host_about                                    3044 non-null   object
#  7   host_response_time                            4461 non-null   object
#  8   host_response_rate                            4461 non-null   object
#  9   host_acceptance_rate                          4552 non-null   object
#  10  host_is_superhost                             4741 non-null   bool
#  11  host_listings_count                           4739 non-null   float64
#  12  host_total_listings_count                     4739 non-null   float64
#  13  host_verifications                            4739 non-null   object
#  14  host_has_profile_pic                          4741 non-null   bool
#  15  host_identity_verified                        4741 non-null   bool
#  16  neighbourhood                                 2977 non-null   object
#  17  neighbourhood_cleansed                        4741 non-null   object
#  18  neighbourhood_group_cleansed                  4741 non-null   bool
#  19  latitude                                      4741 non-null   float64
#  20  longitude                                     4741 non-null   float64
#  21  property_type                                 4741 non-null   object
#  22  room_type                                     4741 non-null   object
#  23  accommodates                                  4741 non-null   int64
#  24  bathrooms                                     4741 non-null   float64
#  25  bathrooms_text                                4741 non-null   object
#  26  bedrooms                                      4741 non-null   float64
#  27  beds                                          4741 non-null   float64
#  28  amenities                                     4741 non-null   object
#  29  minimum_nights                                4741 non-null   int64
#  30  maximum_nights                                4741 non-null   int64
#  31  minimum_nights_avg_ntm                        4741 non-null   float64
#  32  maximum_nights_avg_ntm                        4741 non-null   float64
#  33  calendar_updated                              4741 non-null   bool
#  34  has_availability                              4741 non-null   bool
#  35  availability_30                               4741 non-null   int64
#  36  availability_60                               4741 non-null   int64
#  37  availability_90                               4741 non-null   int64
#  38  availability_365                              4741 non-null   int64
#  39  number_of_reviews                             4741 non-null   int64
#  40  number_of_reviews_ltm                         4741 non-null   int64
#  41  number_of_reviews_l30d                        4741 non-null   int64
#  42  availability_eoy                              4741 non-null   int64
#  43  number_of_reviews_ly                          4741 non-null   int64
#  44  estimated_occupancy_l365d                     4741 non-null   int64
#  45  estimated_revenue_l365d                       4741 non-null   float64
#  46  first_review                                  3968 non-null   object
#  47  last_review                                   3968 non-null   object
#  48  review_scores_rating                          3968 non-null   float64
#  49  review_scores_accuracy                        3967 non-null   float64
#  50  review_scores_cleanliness                     3967 non-null   float64
#  51  review_scores_checkin                         3967 non-null   float64
#  52  review_scores_communication                   3967 non-null   float64
#  53  review_scores_location                        3967 non-null   float64
#  54  review_scores_value                           3967 non-null   float64
#  55  instant_bookable                              4741 non-null   bool
#  56  calculated_host_listings_count                4741 non-null   int64
#  57  calculated_host_listings_count_entire_homes   4741 non-null   int64
#  58  calculated_host_listings_count_private_rooms  4741 non-null   int64
#  59  calculated_host_listings_count_shared_rooms   4741 non-null   int64
#  60  reviews_per_month                             3968 non-null   float64
#  61  price                                         4741 non-null   float64
# dtypes: bool(7), float64(19), int64(17), object(19)
# memory usage: 2.0+ MB

# %%
listings.to_csv('cleaned_listing_v4', index=False)

# %%
calendar.to_csv('cleaned_calendar_v4', index=False)

# %%
pd.set_option('display.max_columns', len(listings.columns))

# %% [markdown]
# # Creating variable that simulates DEMAND q(p)

# %%
calendar.head()
# Out:
#   listing_id       date available  minimum_nights  maximum_nights  price
# 0       3686 2025-03-13      True               1             365   67.0
# 1       3686 2025-03-14      True              31             365   67.0
# 2       3686 2025-03-15      True              31             365   67.0
# 3       3686 2025-03-16      True              31             365   67.0
# 4       3686 2025-03-17      True              31             365   67.0

# %%
calendar = calendar.assign(
    booked = lambda x: np.where(x.available, 0, 1)
)

# %%
calendar.head(3)
# Out:
#    listing_id        date available  minimum_nights  maximum_nights  price  \
# 0        3686  2025-03-13      True             1.0           365.0   67.0
# 1        3686  2025-03-14      True            31.0           365.0   67.0
# 2        3686  2025-03-15      True            31.0           365.0   67.0
#
#    booked
# 0       0
# 1       0
# 2       0

# %%
calendar.groupby('listing_id').booked.mean().head() # probability that the listing is BOOKED (demanded)
# Out:
# listing_id
# 3686    0.000000
# 3943    0.043836
# 4197    0.035616
# 4529    0.509589
# 5589    0.567123
# Name: booked, dtype: float64

# %%
calendar.groupby('listing_id').booked.mean().reset_index(name='occupancy_rate')
# Out:
#                listing_id  occupancy_rate
# 0                    3686        0.000000
# 1                    3943        0.043836
# 2                    4197        0.035616
# 3                    4529        0.509589
# 4                    5589        0.567123
# ...                   ...             ...
# 6176  1373918040709168206        0.219178
# 6177  1373919267253560643        0.736986
# 6178  1373919946920614774        0.049180
# 6179  1374061794031156604        0.863014
# 6180  1374608217603139643        0.000000
#
# [6181 rows x 2 columns]

# %%
occupancy = calendar.groupby('listing_id').booked.mean().reset_index(name='occupancy_rate')

# %%
listings = listings.merge(occupancy, on="listing_id", how="left")

# %%
listings.head()
# Out:
#    listing_id                                               name  \
# 0        3686                                    Vita's Hideaway
# 1        3943                   Historic Rowhouse Near Monuments
# 2        4197                 Capitol Hill Bedroom walk to Metro
# 3        4529                          Bertina's  House Part One
# 4        7103  Lovely guest suite in a quiet but close-in nei...
#
#                                          description  \
# 0  IMPORTANT NOTES<br />* Carefully read and be s...
# 1  You will be staying in high ceiling  bedroom w...
# 2  This is the middle bedroom upstairs in a resto...
# 3  This is  large private  bedroom with plenty of...
# 4  Private guest suite with cathedral ceiling, su...
#
#                                neighborhood_overview  host_name  host_since  \
# 0  We love that our neighborhood is up and coming...       Vita  2008-11-26
# 1  This rowhouse is centrally located in the hear...       Vasa  2008-12-12
# 2  Our area, the Eastern Market neighborhood of C...     Sandra  2008-12-12
# 3  Very quiet neighborhood and it is easy accessi...    Bertina  2008-12-30
# 4                                                NaN  Charlotte  2009-05-18
#
#                                           host_about host_response_time  \
# 0  I am a literary scholar, teacher, poet, vegan ...                NaN
# 1  I travel often and always try to immerse mysel...     within an hour
# 2  I’m a California native who came to work for t...     within an hour
# 3  I am a retried teacher. I enjoy walking and wa...                NaN
# 4  My business is LUXbnb, we offer short-stay fur...     within an hour
#
#   host_response_rate host_acceptance_rate  host_is_superhost  \
# 0                NaN                 100%              False
# 1               100%                  95%               True
# 2               100%                 100%               True
# 3                NaN                  NaN              False
# 4               100%                 100%               True
#
#    host_listings_count  host_total_listings_count  \
# 0                  1.0                        4.0
# 1                  5.0                        5.0
# 2                  2.0                        2.0
# 3                  4.0                        4.0
# 4                 30.0                      106.0
#
#                  host_verifications  host_has_profile_pic  \
# 0  ['email', 'phone', 'work_email']                  True
# 1                ['email', 'phone']                  True
# 2                ['email', 'phone']                  True
# 3                ['email', 'phone']                  True
# 4  ['email', 'phone', 'work_email']                  True
#
#    host_identity_verified            neighbourhood  \
# 0                    True  Neighborhood highlights
# 1                    True  Neighborhood highlights
# 2                    True  Neighborhood highlights
# 3                    True  Neighborhood highlights
# 4                    True                      NaN
#
#                               neighbourhood_cleansed  \
# 0                                 Historic Anacostia
# 1  Edgewood, Bloomingdale, Truxton Circle, Eckington
# 2                         Capitol Hill, Lincoln Park
# 3                       Eastland Gardens, Kenilworth
# 4  Spring Valley, Palisades, Wesley Heights, Foxh...
#
#    neighbourhood_group_cleansed  latitude  longitude  \
# 0                         False  38.86339  -76.98889
# 1                         False  38.91195  -77.00456
# 2                         False  38.88719  -76.99472
# 3                         False  38.90585  -76.94469
# 4                         False  38.91999  -77.09774
#
#                property_type        room_type  accommodates  bathrooms  \
# 0       Private room in home     Private room             1        1.0
# 1  Private room in townhouse     Private room             2        1.0
# 2       Private room in home     Private room             1        1.5
# 3       Private room in home     Private room             2        1.0
# 4         Entire guest suite  Entire home/apt             2        1.0
#
#      bathrooms_text  bedrooms  beds  \
# 0     1 shared bath       1.0   2.0
# 1    1 private bath       1.0   1.0
# 2  1.5 shared baths       1.0   1.0
# 3    1 private bath       1.0   2.0
# 4            1 bath       1.0   2.0
#
#                                            amenities  minimum_nights  \
# 0  ["Shampoo", "Smoke alarm", "Essentials", "Stov...              31
# 1  ["Luggage dropoff allowed", "Window AC unit", ...               1
# 2  ["Luggage dropoff allowed", "Fire pit", "Shamp...               4
# 3  ["Luggage dropoff allowed", "Shampoo", "Smoke ...              30
# 4  ["Luggage dropoff allowed", "Body soap", "Sham...              31
#
#    maximum_nights  minimum_nights_avg_ntm  maximum_nights_avg_ntm  \
# 0             365                    31.0                   365.0
# 1            1125                     1.0                  1125.0
# 2              29                     4.0                  1125.0
# 3            1125                    30.0                  1125.0
# 4            1125                    31.0                   504.5
#
#    calendar_updated  has_availability  availability_30  availability_60  \
# 0             False              True                1                1
# 1             False              True               14               44
# 2             False              True               21               47
# 3             False              True               29               59
# 4             False              True                0                5
#
#    availability_90  availability_365  number_of_reviews  \
# 0                1                 1                 84
# 1               74               349                534
# 2               77               352                 64
# 3               89               179                102
# 4               35               310                 91
#
#    number_of_reviews_ltm  number_of_reviews_l30d  availability_eoy  \
# 0                      0                       0                 0
# 1                     38                       1               278
# 2                      6                       0               281
# 3                      0                       0               179
# 4                      0                       0               239
#
#    number_of_reviews_ly  estimated_occupancy_l365d  estimated_revenue_l365d  \
# 0                     0                          0                      0.0
# 1                    36                        228                  14364.0
# 2                     5                         48                   6144.0
# 3                     0                          0                      0.0
# 4                     0                          0                      0.0
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2010-11-01  2023-08-30                  4.64                    4.73
# 1   2009-05-10  2025-02-19                  4.86                    4.89
# 2   2009-05-14  2025-01-30                  4.87                    4.98
# 3   2009-08-08  2019-07-05                  4.66                    4.80
# 4   2010-03-21  2022-06-03                  4.79                    4.77
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.45                   4.91
# 1                       4.93                   4.94
# 2                       4.89                   5.00
# 3                       4.60                   4.93
# 4                       4.87                   4.94
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.84                    3.91                 4.64
# 1                         4.92                    4.60                 4.77
# 2                         4.98                    4.97                 4.93
# 3                         4.93                    4.51                 4.83
# 4                         4.90                    4.79                 4.81
#
#    instant_bookable  calculated_host_listings_count  \
# 0             False                               1
# 1             False                               5
# 2             False                               2
# 3             False                               2
# 4             False                              27
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                           27
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             5
# 2                                             2
# 3                                             2
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month  price  \
# 0                                            0               0.48   60.0
# 1                                            0               2.77   63.0
# 2                                            0               0.33  128.0
# 3                                            0               0.54   64.0
# 4                                            0               0.50   74.0
#
#    occupancy_rate
# 0        0.000000
# 1        0.043836
# 2        0.035616
# 3        0.509589
# 4        0.150685

# %%
listings.occupancy_rate.describe().T
# Out:
# count    4719.000000
# mean        0.437666
# std         0.313919
# min         0.000000
# 25%         0.147945
# 50%         0.400000
# 75%         0.723288
# max         1.000000
# Name: occupancy_rate, dtype: float64

# %% [markdown]
# We now have an x-variable (price) and a proxy for demand q(p) (occupancy_rate)

# %% [markdown]
# # Attempting to plot the PRICE RESPONSE FUNCTION

# %%
calendar.date.head()
# Out:
# 0    2025-03-13
# 1    2025-03-14
# 2    2025-03-15
# 3    2025-03-16
# 4    2025-03-17
# Name: date, dtype: object

# %%
calendar.tail() # notice that these dates are in 2026
# Out:
#          listing_id        date  available  minimum_nights  maximum_nights  \
# 2255553     8964989  2026-03-10      False               2            1125
# 2255554     8964989  2026-03-11      False               2            1125
# 2255555     8964989  2026-03-12      False               3            1125
# 2255556     8964989  2026-03-13      False               3            1125
# 2255557     8964989  2026-03-14      False               3            1125
#
#          price  booked
# 2255553   99.0       1
# 2255554   99.0       1
# 2255555   99.0       1
# 2255556   99.0       1
# 2255557   99.0       1

# %% [markdown]
# **NOTE ON MAJOR ASSUMPTION**: The AVAILABLE column indicates whether the listing is open for booking on that date. Does not confirm whether or not it IS or HAS BEEN posted that day.
#
#  - True == available for booking
#  - False == not available for booking (it's either booked or currently blocked by host, at time of snapshot of data).
#
# When AVAILABLE == False, we don't know if the listing was actually ever available, if the listing was removed because no one was booking (demand low), or some other reason.
#
# When AVAILABLE == True, we don't know if the listing was just posted (no timestamp).
#
# AVAILABLE == FALSE assumption may OVERESTIMATE DEMAND.
# AVAILABLE == TRUE assumption may further blur the lines. Reflects SUPPLY, rather than DEMAND.

# %% [markdown]
# **NOTES ON THE DATA**
# This data is published by Airbnb and projects listings for up to a year into the future.
#
# The data was scrapped by Airbnb on March 13th. Therefore, dates AFTER March 13 2025 (into 2026) are simply FUTURE SCHEDULED PROJECTION. This tells us SUPPLY, rather than REALIZED DEMAND.
#
# We can't predict nor infer HOW customers will respond to these future prices yet - because they simply haven't been realized to the market yet.

# %% [markdown]
# **ESTIMATING THE PRICE-RESPONSE FUNCTION AND 2026 LISTINGS**
# We need OBSERVED DEMAND OUTCOMES.
# Future listings (Feb-March 2026) don't serve as proxies for real demand behavior - they're placeholders.
# Including them would:
#  - Make demand look like there is none more frequently than reality.
#  - Bias elasticity estimates (demand will seem unresponsive to changing price)
#  - Bias revenue estimates.

# %% [markdown]
# **Defining the relevant data**
# Want listings that reflect recent and realized demand.
#
# DECISION:
#  - Drop all 2026 listings (consider setting aside for future forecasting tests).
#  - Keep only postings made before or shortly after March 13 (later listings likely represent demand planning).

# %%
calendar.head()
# Out:
#    listing_id        date  available  minimum_nights  maximum_nights  price  \
# 0        3686  2025-03-13       True               1             365   67.0
# 1        3686  2025-03-14       True              31             365   67.0
# 2        3686  2025-03-15       True              31             365   67.0
# 3        3686  2025-03-16       True              31             365   67.0
# 4        3686  2025-03-17       True              31             365   67.0
#
#    booked
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# ## Exploring data to determine practical filtering procedure

# %% [markdown]
# **GOAL**: Filter out and set aside anything that is FUTURE-DATE, EMPTY, or INACTIVE

# %% [markdown]
# ### Removing all 2026 listings

# %% [markdown]
# Intend to set them aside. Potentially later use to either:
#  - Forecast testing or LLM scenario generation. Potentially "How would fitted model predict 2026 occupancy given price?" or "Given listing's historical elasticity (March 2025, for example), what's the expected occupancy in March 2026?"

# %%
_2026 = pd.to_datetime('2026-01-01')

# %%
_2026_calendar = calendar.loc[lambda x: pd.to_datetime(x.date) >= _2026]

# %%
_2026_calendar.head(1)
# Out:
#      listing_id        date  available  minimum_nights  maximum_nights  price  \
# 294        3686  2026-01-01       True              31             365   67.0
#
#      booked
# 294       0

# %%
calendar.head(3)
# Out:
#    listing_id        date  available  minimum_nights  maximum_nights  price  \
# 0        3686  2025-03-13       True               1             365   67.0
# 1        3686  2025-03-14       True              31             365   67.0
# 2        3686  2025-03-15       True              31             365   67.0
#
#    booked
# 0       0
# 1       0
# 2       0

# %% [markdown]
# **ISSUE**
# Plan was to filter out and set aside listings that don't represent DEMAND, any SUPPLY related postings (e.g., 2026 listings). However, the same *listing_id's* occassionally appear in both 2025 and 2026 entries because the ID represents a single Airbnb listing that continues to exist.
#  - Each listting actually has many rows because each date represents a date Airbnb PUBLISHED that posting.
#
# Filtering out using LISTING_ID could potentially remove the ENTIRE LISTING

# %%
listings.head().iloc[:,-1]
# Out:
# 0    0.000000
# 1    0.043836
# 2    0.035616
# 3    0.509589
# 4    0.150685
# Name: occupancy_rate, dtype: float64

# %%
# dropping occupancy_rate because not accurate representation for demand yet
listings.drop(columns=["occupancy_rate"], inplace=True)

# %%
# dropping derived features from CALENDAR because not accurate yet
calendar.drop(columns=["booked"], inplace=True)

# %% [markdown]
# *QUESTION*
#
# How much data would we have to use for fitting model if we only include instances UP to the scrap date?

# %%
scrap_date = pd.to_datetime('2025-03-13')

# %%
calendar.sort_values(by="date")
# Out:
#                   listing_id        date  available  minimum_nights  \
# 0                       3686  2025-03-13       True               1
# 1428502  1010705782683167311  2025-03-13      False               1
# 1428137  1010653751695329863  2025-03-13      False               3
# 363965              23148309  2025-03-13      False               2
# 1427772  1010486489906800727  2025-03-13      False             183
# ...                      ...         ...        ...             ...
# 141647              10311634  2026-03-14      False               3
# 1837736  1224731147854068394  2026-03-14      False               2
# 1497738  1049236007638467900  2026-03-14      False               1
# 805312              50189968  2026-03-14       True               1
# 2255557              8964989  2026-03-14      False               3
#
#          maximum_nights  price
# 0                   365   67.0
# 1428502            1125  158.0
# 1428137               7  130.0
# 363965             1125  115.0
# 1427772            1125  240.0
# ...                 ...    ...
# 141647             1125  180.0
# 1837736              28  229.0
# 1497738            1125   80.0
# 805312             1125  129.0
# 2255557            1125   99.0
#
# [2255558 rows x 6 columns]

# %%
calendar.loc[lambda x:
             pd.to_datetime(x.date) <= scrap_date].sort_values(by="date")

# not sure if enough for training
# Out:
#                   listing_id        date  available  minimum_nights  \
# 0                       3686  2025-03-13       True               1
# 1498104  1049371086899899688  2025-03-13      False               1
# 1496279  1048588275488319161  2025-03-13      False               1
# 1495914  1047916172762233921  2025-03-13      False               1
# 1495549  1047230201172107759  2025-03-13      False               2
# ...                      ...         ...        ...             ...
# 726461              47451426  2025-03-13      False               4
# 726096              47443903  2025-03-13      False              14
# 725731              47431222  2025-03-13      False               1
# 729746              47560691  2025-03-13      False               1
# 2254828              8933705  2025-03-13      False              31
#
#          maximum_nights  price
# 0                   365   67.0
# 1498104              29   85.0
# 1496279             365  165.0
# 1495914            1125  125.0
# 1495549            1125  577.0
# ...                 ...    ...
# 726461             1125  220.0
# 726096              730   35.0
# 725731             1125   70.0
# 729746               29   77.0
# 2254828            1125  192.0
#
# [4921 rows x 6 columns]

# %%
potential_buffer_date = pd.to_datetime("2025-06-01")
# potentially keep if these postings were available to public at time of scrapping

# %%
calendar.loc[lambda x:
              pd.to_datetime(x.date) <= potential_buffer_date
].shape[0] # 499014 listings made BEFORE (or on) June 01 2025
# Out:
# 271141

# %%
relevant_calendar = calendar.loc[lambda x:
              pd.to_datetime(x.date) <= potential_buffer_date
] # candidate instances to derive price response function

# %%
relevant_calendar.shape
# Out:
# (271141, 7)

# %% [markdown]
# ## Adding BOOKED feature (proxy for demand) to postings more than likely representative of DEMAND

# %%
relevant_calendar.head()
# Out:
#    listing_id        date  available  minimum_nights  maximum_nights  price
# 0        3686  2025-03-13       True               1             365   67.0
# 1        3686  2025-03-14       True              31             365   67.0
# 2        3686  2025-03-15       True              31             365   67.0
# 3        3686  2025-03-16       True              31             365   67.0
# 4        3686  2025-03-17       True              31             365   67.0

# %%
relevant_calendar = relevant_calendar.assign(
    booked = lambda x: np.where(x.available, 0, 1) # Booked=1 if Available=False
)

# %%
relevant_calendar
# Out:
#                  listing_id       date available  minimum_nights  \
# 0                      3686 2025-03-13      True               1
# 1                      3686 2025-03-14      True              31
# 2                      3686 2025-03-15      True              31
# 3                      3686 2025-03-16      True              31
# 4                      3686 2025-03-17      True              31
# ...                     ...        ...       ...             ...
# 1225591  861857172153830345 2025-05-28      True               2
# 1225592  861857172153830345 2025-05-29     False               2
# 1225593  861857172153830345 2025-05-30     False               3
# 1225594  861857172153830345 2025-05-31     False               3
# 1225595  861857172153830345 2025-06-01     False               2
#
#          maximum_nights   price  booked
# 0                   365    67.0       0
# 1                   365    67.0       0
# 2                   365    67.0       0
# 3                   365    67.0       0
# 4                   365    67.0       0
# ...                 ...     ...     ...
# 1225591              10  5000.0       0
# 1225592              10  5000.0       1
# 1225593              10  5000.0       1
# 1225594              10  5000.0       1
# 1225595              10  5000.0       1
#
# [271141 rows x 7 columns]

# %% [markdown]
# ## INSIGHT:
# Observe that (above), in using the calendar data to construct a proxy for realized demand, we must be careful not to double-count the same booking across consecutive days.
#
# The same five rows above represent a SINGLE BOOKING, not five separate units of booking/demand. If we aren't careful, we could overstand demand rather easily here.

# %% [markdown]
# NOTE: It is positive to see that listings towards the end of May were indeed viable and available listings, as the listing (830345) couldn't have been booked if it wasn't available.

# %% [markdown]
# # Attempting to develop a strategy to identify "Repeat" Bookings

# %% [markdown]
# Idea - count ONLY unique bookings (the first instance/day the listing transitions from available to booked).

# %%
calendar
# Out:
#                  listing_id       date available  minimum_nights  \
# 0                      3686 2025-03-13      True               1
# 1                      3686 2025-03-14      True              31
# 2                      3686 2025-03-15      True              31
# 3                      3686 2025-03-16      True              31
# 4                      3686 2025-03-17      True              31
# ...                     ...        ...       ...             ...
# 1225875  861857172153830345 2026-03-08      True               5
# 1225876  861857172153830345 2026-03-09      True               5
# 1225877  861857172153830345 2026-03-10      True               5
# 1225878  861857172153830345 2026-03-11      True               5
# 1225879  861857172153830345 2026-03-12      True               5
#
#          maximum_nights   price  booked
# 0                   365    67.0       0
# 1                   365    67.0       0
# 2                   365    67.0       0
# 3                   365    67.0       0
# 4                   365    67.0       0
# ...                 ...     ...     ...
# 1225875              10  5000.0       0
# 1225876              10  5000.0       0
# 1225877              10  5000.0       0
# 1225878              10  5000.0       0
# 1225879              10  5000.0       0
#
# [1225880 rows x 7 columns]

# %%
pd.Series(calendar.sort_values(['listing_id', 'date']).index).equals(pd.Series(calendar.index.values))
# need ensure that each listing is sorted in proper sequential manner
# Out:
# False

# %%
calendar = calendar.sort_values(['listing_id', 'date'])

# %%
calendar_copy = calendar.assign(
    new_booking = (calendar.available.shift(1) == True # return all rows in which the row prior to it has a True value in available ..
 ) & (calendar.available == False # ... and the row in question has available = FALSE
                                         ) & (
                                             calendar.listing_id == calendar.listing_id.shift(1)
                                         ) # ... and the rows listing_id equals the listing_id of the row before it
)

# %%
calendar_copy.loc[
    (calendar_copy.new_booking==True) & (calendar_copy.new_booking.shift(1) == False)
]
# Out:
#                  listing_id       date available  minimum_nights  \
# 373                    3943 2025-03-20     False               1
# 387                    3943 2025-04-03     False               1
# 755                    4197 2025-04-06     False               4
# 772                    4197 2025-04-23     False               4
# 1276                   4529 2025-09-09     False              30
# ...                     ...        ...       ...             ...
# 1225613  861857172153830345 2025-06-19     False               2
# 1225627  861857172153830345 2025-07-03     False               2
# 1225633  861857172153830345 2025-07-09     False               2
# 1225641  861857172153830345 2025-07-17     False               2
# 1225646  861857172153830345 2025-07-22     False               2
#
#          maximum_nights   price  booked  new_booking
# 373                1125    55.0       1         True
# 387                1125    55.0       1         True
# 755                1125    83.0       1         True
# 772                1125    83.0       1         True
# 1276               1125    55.0       1         True
# ...                 ...     ...     ...          ...
# 1225613              10  5000.0       1         True
# 1225627              10  5000.0       1         True
# 1225633              10  5000.0       1         True
# 1225641              10  5000.0       1         True
# 1225646              10  5000.0       1         True
#
# [16882 rows x 8 columns]

# %%
calendar_copy.loc[lambda x: x.listing_id == 4197].head(25)
# Out:
#     listing_id       date available  minimum_nights  maximum_nights  price  \
# 731       4197 2025-03-13     False               4            1125   83.0
# 732       4197 2025-03-14     False               4            1125   83.0
# 733       4197 2025-03-15     False               4            1125   83.0
# 734       4197 2025-03-16     False               4            1125   83.0
# 735       4197 2025-03-17      True               4            1125   83.0
# 736       4197 2025-03-18      True               4            1125   83.0
# 737       4197 2025-03-19      True               4            1125   83.0
# 738       4197 2025-03-20      True               4            1125   83.0
# 739       4197 2025-03-21      True               4            1125   83.0
# 740       4197 2025-03-22      True               4            1125   83.0
# 741       4197 2025-03-23      True               4            1125   83.0
# 742       4197 2025-03-24      True               4            1125   83.0
# 743       4197 2025-03-25      True               4            1125   83.0
# 744       4197 2025-03-26      True               4            1125   83.0
# 745       4197 2025-03-27      True               4            1125   83.0
# 746       4197 2025-03-28      True               4            1125   83.0
# 747       4197 2025-03-29      True               4            1125   83.0
# 748       4197 2025-03-30      True               4            1125   83.0
# 749       4197 2025-03-31      True               4            1125   83.0
# 750       4197 2025-04-01      True               4            1125   83.0
# 751       4197 2025-04-02      True               4            1125   83.0
# 752       4197 2025-04-03      True               4            1125   83.0
# 753       4197 2025-04-04      True               4            1125   83.0
# 754       4197 2025-04-05      True               4            1125   83.0
# 755       4197 2025-04-06     False               4            1125   83.0
#
#      booked  new_booking
# 731       1        False
# 732       1        False
# 733       1        False
# 734       1        False
# 735       0        False
# 736       0        False
# 737       0        False
# 738       0        False
# 739       0        False
# 740       0        False
# 741       0        False
# 742       0        False
# 743       0        False
# 744       0        False
# 745       0        False
# 746       0        False
# 747       0        False
# 748       0        False
# 749       0        False
# 750       0        False
# 751       0        False
# 752       0        False
# 753       0        False
# 754       0        False
# 755       1         True

# %% [markdown]
# # INSIGHT FROM ABOVE:
# Notice that, because the dataset snapshot begins at the onset of March 13th, the listings, such as the one above for example, that were unavailable (due in all likelihood to being booked) dont register as a NEW BOOKING.
#
# This is because the observation window (Airbnb listings in Washington DC made on or after March 13th 2025) started AFTER listings were already available and welcominging guests (demand was being realized).
#
# If we don't handle this properly, we may:
#  - UNDER-COUNT BOOKINGS early on in the data (all bookings that began and were made before March 13th)
#  - bias our demand proxy downward, especially at the onset of our modeling.
#  - distort the pricing/demand relationships hidden in the data.

# %%
calendar_copy
# Out:
#                  listing_id       date available  minimum_nights  \
# 0                      3686 2025-03-13      True               1
# 1                      3686 2025-03-14      True              31
# 2                      3686 2025-03-15      True              31
# 3                      3686 2025-03-16      True              31
# 4                      3686 2025-03-17      True              31
# ...                     ...        ...       ...             ...
# 1225875  861857172153830345 2026-03-08      True               5
# 1225876  861857172153830345 2026-03-09      True               5
# 1225877  861857172153830345 2026-03-10      True               5
# 1225878  861857172153830345 2026-03-11      True               5
# 1225879  861857172153830345 2026-03-12      True               5
#
#          maximum_nights   price  booked  new_booking prev_availability
# 0                   365    67.0       0        False               NaN
# 1                   365    67.0       0        False              True
# 2                   365    67.0       0        False              True
# 3                   365    67.0       0        False              True
# 4                   365    67.0       0        False              True
# ...                 ...     ...     ...          ...               ...
# 1225875              10  5000.0       0        False              True
# 1225876              10  5000.0       0        False              True
# 1225877              10  5000.0       0        False              True
# 1225878              10  5000.0       0        False              True
# 1225879              10  5000.0       0        False              True
#
# [1225880 rows x 9 columns]

# %%
g = calendar_copy.groupby('listing_id', sort=False)

# %%
calendar_copy.groupby('listing_id', sort=False).available.shift(1)
# Out:
# 0           NaN
# 1          True
# 2          True
# 3          True
# 4          True
#            ...
# 1225875    True
# 1225876    True
# 1225877    True
# 1225878    True
# 1225879    True
# Name: available, Length: 1225880, dtype: object

# %%
calendar_copy = calendar_copy.assign(
    prev_availability = g.available.shift(1)
) # each rows PREV_AVAILABILITY column equals that listing's availability from the previous day

# %%
calendar = calendar_copy.assign(
    new_booking = (calendar_copy.available==False) & (
        calendar_copy.prev_availability.fillna(True)
    )
) # NEW_BOOKING holds TRUE only if the listing had no previously posted availability recorded (initial posting occured outside of window)
# AND the instance must have just switched from AVAILABLE=TRUE to AVAILABLE=FALSE (demand realized)
# Out:
# /tmp/ipython-input-4162547285.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   calendar_copy.prev_availability.fillna(True)

# %%
calendar.drop(columns=['prev_availability'], inplace=True)

# %%
calendar.head() # new_booking==True means new booking started on that date (demand realized)
# Out:
#   listing_id       date available  minimum_nights  maximum_nights  price  \
# 0       3686 2025-03-13      True               1             365   67.0
# 1       3686 2025-03-14      True              31             365   67.0
# 2       3686 2025-03-15      True              31             365   67.0
# 3       3686 2025-03-16      True              31             365   67.0
# 4       3686 2025-03-17      True              31             365   67.0
#
#    booked  new_booking
# 0       0        False
# 1       0        False
# 2       0        False
# 3       0        False
# 4       0        False

# %% [markdown]
# ### Deriving new column to assess and account for continuous bookings

# %% [markdown]
# Idea here is that each initial TRUE instance in NEW_BOOKING will start a new BOOKING with a new unique booking_id. The booking_id doesn't change until a new_booking (demand) is realized for the property

# %%
calendar = calendar.assign(
    booking_id = lambda x: x.groupby('listing_id').new_booking.cumsum()
) # gives every BOOKING a unique ID within the listing_id of the property

# %%
calendar
# Out:
#                  listing_id       date available  minimum_nights  \
# 0                      3686 2025-03-13      True               1
# 1                      3686 2025-03-14      True              31
# 2                      3686 2025-03-15      True              31
# 3                      3686 2025-03-16      True              31
# 4                      3686 2025-03-17      True              31
# ...                     ...        ...       ...             ...
# 1225875  861857172153830345 2026-03-08      True               5
# 1225876  861857172153830345 2026-03-09      True               5
# 1225877  861857172153830345 2026-03-10      True               5
# 1225878  861857172153830345 2026-03-11      True               5
# 1225879  861857172153830345 2026-03-12      True               5
#
#          maximum_nights   price  booked  new_booking  booking_id
# 0                   365    67.0       0        False           0
# 1                   365    67.0       0        False           0
# 2                   365    67.0       0        False           0
# 3                   365    67.0       0        False           0
# 4                   365    67.0       0        False           0
# ...                 ...     ...     ...          ...         ...
# 1225875              10  5000.0       0        False          14
# 1225876              10  5000.0       0        False          14
# 1225877              10  5000.0       0        False          14
# 1225878              10  5000.0       0        False          14
# 1225879              10  5000.0       0        False          14
#
# [1225880 rows x 9 columns]

# %% [markdown]
# Above logic isn't as efficient because each booking_id should only describe instances in which the listing is ACTUALLY being occupied

# %%
calendar = calendar.assign(
    booking_seq = lambda x: x.groupby('listing_id').new_booking.cumsum() # column to run count of booking starts within each listing
).drop(columns=['booking_id'])

# %%
booked_condition = (calendar.available==False) & (calendar.booked==1)
# instance holds TRUE only if actually booked

# %%
calendar = calendar.assign(
    booking_id = calendar.booking_seq.where(booked_condition) # booking label only kept on TRUE booked days; NA otherwise
)

# %%
calendar.loc[lambda x: x.available==False]
# Out:
#                  listing_id       date available  minimum_nights  \
# 366                    3943 2025-03-13     False               1
# 367                    3943 2025-03-14     False               1
# 373                    3943 2025-03-20     False               1
# 374                    3943 2025-03-21     False               1
# 375                    3943 2025-03-22     False               1
# ...                     ...        ...       ...             ...
# 1225643  861857172153830345 2025-07-19     False               4
# 1225646  861857172153830345 2025-07-22     False               2
# 1225647  861857172153830345 2025-07-23     False               2
# 1225648  861857172153830345 2025-07-24     False               2
# 1225649  861857172153830345 2025-07-25     False               2
#
#          maximum_nights   price  booked  new_booking  booking_seq  booking_id
# 366                1125    55.0       1         True            1         1.0
# 367                1125    55.0       1        False            1         1.0
# 373                1125    55.0       1         True            2         2.0
# 374                1125    55.0       1        False            2         2.0
# 375                1125    55.0       1        False            2         2.0
# ...                 ...     ...     ...          ...          ...         ...
# 1225643              10  5000.0       1        False           13        13.0
# 1225646              10  5000.0       1         True           14        14.0
# 1225647              10  5000.0       1        False           14        14.0
# 1225648              10  5000.0       1        False           14        14.0
# 1225649              10  5000.0       1        False           14        14.0
#
# [600380 rows x 10 columns]

# %% [markdown]
# ### Attempting to make column that tracks length of stay of booking

# %%
stay_length = (calendar.loc[booked_condition].groupby(
    ['listing_id', 'booking_id']
).date.size().rename('stay_length').reset_index())

# %%
stay_length.head()
# Out:
#    listing_id  booking_id  stay_length
# 0        3943         1.0            2
# 1        3943         2.0           11
# 2        3943         3.0            3
# 3        4197         1.0            4
# 4        4197         2.0            5

# %% [markdown]
# ## Attempting to capture start and end dates of bookings to explicity define duration time stamped interval for each realized booking.

# %% [markdown]
# Idea is that this allowes for time-based demand analysis (seasonality/weekday effects (i.e., on what day doo most check-ins occur)

# %%
start_end_dates = (calendar.loc[booked_condition].groupby(
    ['listing_id', 'booking_id']
).date.agg(start_date='min', end_date='max').reset_index())

# %%
start_end_dates.head()
# Out:
#    listing_id  booking_id start_date   end_date
# 0        3943         1.0 2025-03-13 2025-03-14
# 1        3943         2.0 2025-03-20 2025-03-30
# 2        3943         3.0 2025-04-03 2025-04-05
# 3        4197         1.0 2025-03-13 2025-03-16
# 4        4197         2.0 2025-04-06 2025-04-10

# %% [markdown]
# ### Merging back derived features to calendar data

# %%
stay_length_copy = stay_length[['listing_id', 'booking_id', 'stay_length']].copy()

# %%
start_end_dates_copy = start_end_dates[
    ['listing_id', 'booking_id', 'start_date', 'end_date']
].copy()

# %%
booking_info = stay_length_copy.merge(
    start_end_dates, on=['listing_id', 'booking_id'], how='left',
    validate='one_to_one'
)

# %% [markdown]
# ### Making sure datatypes match on the dimensions being joined

# %%
booking_info = booking_info.assign(
    listing_id = lambda x: x.listing_id.astype('object')
)

# %%
booking_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19700 entries, 0 to 19699
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   listing_id   19700 non-null  object
#  1   booking_id   19700 non-null  float64
#  2   stay_length  19700 non-null  int64
#  3   start_date   19700 non-null  datetime64[ns]
#  4   end_date     19700 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 769.7+ KB

# %%
booking_info.head()
# Out:
#   listing_id  booking_id  stay_length start_date   end_date
# 0       3943         1.0            2 2025-03-13 2025-03-14
# 1       3943         2.0           11 2025-03-20 2025-03-30
# 2       3943         3.0            3 2025-04-03 2025-04-05
# 3       4197         1.0            4 2025-03-13 2025-03-16
# 4       4197         2.0            5 2025-04-06 2025-04-10

# %%
booking_info = booking_info.assign(
    stay_length = lambda x: x.stay_length.astype('float64')
)

# %%
booking_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19700 entries, 0 to 19699
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   listing_id   19700 non-null  object
#  1   booking_id   19700 non-null  float64
#  2   stay_length  19700 non-null  float64
#  3   start_date   19700 non-null  datetime64[ns]
#  4   end_date     19700 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), object(1)
# memory usage: 769.7+ KB

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1225880 entries, 0 to 1225879
# Data columns (total 13 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   listing_id      1225880 non-null  object
#  1   date            1225880 non-null  datetime64[ns]
#  2   available       1225880 non-null  object
#  3   minimum_nights  1225880 non-null  int64
#  4   maximum_nights  1225880 non-null  int64
#  5   price           1225880 non-null  float64
#  6   booked          1225880 non-null  int64
#  7   new_booking     1225880 non-null  bool
#  8   booking_seq     1225880 non-null  int64
#  9   booking_id      600380 non-null   float64
#  10  stay_length     600380 non-null   float64
#  11  start_date      600380 non-null   datetime64[ns]
#  12  end_date        600380 non-null   datetime64[ns]
# dtypes: bool(1), datetime64[ns](3), float64(3), int64(4), object(2)
# memory usage: 113.4+ MB

# %%
booking_info = booking_info.assign(
    stay_length = lambda x: x.stay_length.astype('Int64')
)

# %%
calendar = calendar.assign(
    stay_length = lambda x: x.stay_length.astype('Int64') # creates a nullable column that holds integers but accepts NULL values
)

# %%
calendar = calendar.drop(columns=['stay_length', 'start_date', 'end_date']).merge(
    booking_info, on=['listing_id', 'booking_id'], how='left',
    validate='many_to_one'
)

# %%
calendar.loc[lambda x: x.available==False]
# Out:
#                  listing_id       date available  minimum_nights  \
# 366                    3943 2025-03-13     False               1
# 367                    3943 2025-03-14     False               1
# 373                    3943 2025-03-20     False               1
# 374                    3943 2025-03-21     False               1
# 375                    3943 2025-03-22     False               1
# ...                     ...        ...       ...             ...
# 1225643  861857172153830345 2025-07-19     False               4
# 1225646  861857172153830345 2025-07-22     False               2
# 1225647  861857172153830345 2025-07-23     False               2
# 1225648  861857172153830345 2025-07-24     False               2
# 1225649  861857172153830345 2025-07-25     False               2
#
#          maximum_nights   price  booked  new_booking  booking_seq  booking_id  \
# 366                1125    55.0       1         True            1         1.0
# 367                1125    55.0       1        False            1         1.0
# 373                1125    55.0       1         True            2         2.0
# 374                1125    55.0       1        False            2         2.0
# 375                1125    55.0       1        False            2         2.0
# ...                 ...     ...     ...          ...          ...         ...
# 1225643              10  5000.0       1        False           13        13.0
# 1225646              10  5000.0       1         True           14        14.0
# 1225647              10  5000.0       1        False           14        14.0
# 1225648              10  5000.0       1        False           14        14.0
# 1225649              10  5000.0       1        False           14        14.0
#
#          stay_length start_date   end_date
# 366                2 2025-03-13 2025-03-14
# 367                2 2025-03-13 2025-03-14
# 373               11 2025-03-20 2025-03-30
# 374               11 2025-03-20 2025-03-30
# 375               11 2025-03-20 2025-03-30
# ...              ...        ...        ...
# 1225643            3 2025-07-17 2025-07-19
# 1225646            4 2025-07-22 2025-07-25
# 1225647            4 2025-07-22 2025-07-25
# 1225648            4 2025-07-22 2025-07-25
# 1225649            4 2025-07-22 2025-07-25
#
# [600380 rows x 13 columns]

# %% [markdown]
# Because it is evident that within the CALENDAR level data, a single booking occupiers multiple rows, we are going to make a separate booking_table, in which each row represent a SINGULAR continuous stay).
#
# May prove useful down the line.

# %%
booking_level = calendar.loc[calendar.new_booking].rename(
    columns={'date':'booking_start_date'}
)[['listing_id', 'booking_id', 'booking_start_date', 'stay_length',
   'start_date', 'end_date']]

# %%
booking_level.head(30)
# Out:
#      listing_id  booking_id booking_start_date  stay_length start_date  \
# 366        3943         1.0         2025-03-13          2.0 2025-03-13
# 373        3943         2.0         2025-03-20         11.0 2025-03-20
# 387        3943         3.0         2025-04-03          3.0 2025-04-03
# 731        4197         1.0         2025-03-13          4.0 2025-03-13
# 755        4197         2.0         2025-04-06          5.0 2025-04-06
# 772        4197         3.0         2025-04-23          4.0 2025-04-23
# 1096       4529         1.0         2025-03-13          1.0 2025-03-13
# 1276       4529         2.0         2025-09-09        185.0 2025-09-09
# 1461       5589         1.0         2025-03-13          7.0 2025-03-13
# 1495       5589         2.0         2025-04-16         15.0 2025-04-16
# 1641       5589         3.0         2025-09-09        185.0 2025-09-09
# 1826       7103         1.0         2025-03-13         55.0 2025-03-13
# 2193      11785         1.0         2025-03-16         76.0 2025-03-16
# 2461      11785         2.0         2025-12-09         95.0 2025-12-09
# 2556      12442         1.0         2025-03-13         56.0 2025-03-13
# 2623      12442         2.0         2025-05-19         91.0 2025-05-19
# 2921      13744         1.0         2025-03-13        141.0 2025-03-13
# 3101      13744         2.0         2025-09-09        185.0 2025-09-09
# 3301      14218         1.0         2025-03-28         37.0 2025-03-28
# 3358      14218         2.0         2025-05-24         71.0 2025-05-24
# 3651      17131         1.0         2025-03-13        140.0 2025-03-13
# 4016      27682         1.0         2025-03-13         52.0 2025-03-13
# 4095      27682         2.0         2025-05-31         93.0 2025-05-31
# 4381      32087         1.0         2025-03-13          2.0 2025-03-13
# 4393      32087         2.0         2025-03-25          6.0 2025-03-25
# 4405      32087         3.0         2025-04-06          3.0 2025-04-06
# 4440      32087         4.0         2025-05-11          8.0 2025-05-11
# 4460      32087         5.0         2025-05-31          7.0 2025-05-31
# 4561      32087         6.0         2025-09-09        185.0 2025-09-09
# 4746      52092         1.0         2025-03-13         78.0 2025-03-13
#
#        end_date
# 366  2025-03-14
# 373  2025-03-30
# 387  2025-04-05
# 731  2025-03-16
# 755  2025-04-10
# 772  2025-04-26
# 1096 2025-03-13
# 1276 2026-03-12
# 1461 2025-03-19
# 1495 2025-04-30
# 1641 2026-03-12
# 1826 2025-05-06
# 2193 2025-05-30
# 2461 2026-03-13
# 2556 2025-05-07
# 2623 2025-08-17
# 2921 2025-07-31
# 3101 2026-03-12
# 3301 2025-05-03
# 3358 2025-08-02
# 3651 2025-07-30
# 4016 2025-05-03
# 4095 2025-08-31
# 4381 2025-03-14
# 4393 2025-03-30
# 4405 2025-04-08
# 4440 2025-05-18
# 4460 2025-06-06
# 4561 2026-03-12
# 4746 2025-05-29

# %%
calendar_level = calendar.copy()

# %%
calendar_level.head()
# Out:
#   listing_id       date available  minimum_nights  maximum_nights  price  \
# 0       3686 2025-03-13      True               1             365   67.0
# 1       3686 2025-03-14      True              31             365   67.0
# 2       3686 2025-03-15      True              31             365   67.0
# 3       3686 2025-03-16      True              31             365   67.0
# 4       3686 2025-03-17      True              31             365   67.0
#
#    booked  new_booking  booking_seq  booking_id  stay_length start_date  \
# 0       0        False            0         NaN         <NA>        NaT
# 1       0        False            0         NaN         <NA>        NaT
# 2       0        False            0         NaN         <NA>        NaT
# 3       0        False            0         NaN         <NA>        NaT
# 4       0        False            0         NaN         <NA>        NaT
#
#   end_date
# 0      NaT
# 1      NaT
# 2      NaT
# 3      NaT
# 4      NaT

# %%
calendar_level.to_csv('calendar_level_csv', index=False)

# %%
booking_level.to_csv('booking_level_csv', index=False)

# %% [markdown]
# ## Can now begin moving onto next phase - modeling the underlying Price Response function, etc.
